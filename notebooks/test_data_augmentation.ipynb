# %%
import numpy as np
from scipy.misc import imread, imsave
import matplotlib.pyplot as plt

# %%
from AxonDeepSeg.data_management import input_data

# %%
from AxonDeepSeg.config_tools import default_dataset_configuration

# %%
trainingset_path = '../data/SEM_3c_512/training/'
data_aug = {"type":'all',
                "random_rotation":{
                    "activate":True,
                    "order":1,
                    "low_bound":70,
                    "high_bound":89
                }
            }
dataset_config = default_dataset_configuration()

# %%
data = input_data.input_data(trainingset_path, dataset_config, batch_size=1)

# %%
batch_x, batch_y, batch_w = data.next_batch_WithWeights(augmented_data_=data_aug, data_aug_verbose=2)
# Out:
# rotation angle:  [ 70.50510217]

# %%
x = batch_x[0]
y = 255*batch_y[0]

# %%
plt.imshow(x)
plt.colorbar()
plt.show();

# %%
plt.figure(figsize=(12,12))
plt.subplot(2,2,1)
plt.imshow(y[:,:,0])
plt.subplot(2,2,2)
plt.imshow(y[:,:,1])
plt.subplot(2,2,3)
plt.imshow(y[:,:,2])
plt.subplot(2,2,4)
plt.imshow(batch_w[0])
plt.colorbar()
plt.show();

# %%
plt.figure(figsize=(15,10))
plt.subplot(1,2,1)
plt.imshow(x)
plt.subplot(1,2,2)
plt.imshow(batch_w[0])
plt.colorbar()
plt.show();

# %%
plt.figure(figsize=(15,10))
plt.subplot(1,2,1)
plt.imshow(x)
plt.subplot(1,2,2)
plt.imshow(batch_w[0])
plt.colorbar()
plt.show();

# %% [markdown]
# # TEST DU PREPROCESSING

# %% [markdown]
# Test du preprocessing

# %%
import AxonDeepSeg.patch_management_tools as pmt

# %%
img = imread("../data/SEM_3c_512/training/Train/image_14.png")

# %%
plt.figure(figsize=(15,15))
plt.imshow(preprocessed_leg_img)
plt.colorbar()
plt.show();

# %%
preprocessed_img = pmt.apply_preprocess(img, default_dataset_configuration()["dataset_mean"],  default_dataset_configuration()["dataset_variance"])
preprocessed_leg_img = pmt.apply_legacy_preprocess(img)

# %%
plt.figure(figsize=(16,16))
plt.subplot(2,2,1)
plt.imshow(img, cmap='jet')
plt.colorbar()
plt.subplot(2,2,2)
plt.imshow(preprocessed_img, cmap='jet')
plt.colorbar()
plt.subplot(2,2,3)
plt.imshow(preprocessed_leg_img, cmap='jet')
plt.colorbar()
plt.show();

# %%
diff = preprocessed_img - preprocessed_leg_img

plt.figure(figsize=(8,8))
plt.imshow(diff, cmap="jet")
plt.colorbar()
plt.show();

# %%
n, bins, patches = plt.hist(preprocessed_img, bins=50)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-1187113f9e7b> in <module>()
# ----> 1 n, bins, patches = plt.hist(preprocessed_img, bins=50)
#
# /Users/maxwab/.virtualenvs/ads-tf-updated/lib/python2.7/site-packages/matplotlib/pyplot.pyc in hist(x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, hold, data, **kwargs)
#    3079                       histtype=histtype, align=align, orientation=orientation,
#    3080                       rwidth=rwidth, log=log, color=color, label=label,
# -> 3081                       stacked=stacked, data=data, **kwargs)
#    3082     finally:
#    3083         ax._hold = washold
#
# /Users/maxwab/.virtualenvs/ads-tf-updated/lib/python2.7/site-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
# ...
