# %%
import json
import os
import time

# %%
# Description du fichier config :
# network_learning_rate : float : No idea, but certainly linked to the back propagation ? Default : 0.0005.
# network_n_classes : int : number of labels in the output. Default : 2.
# dropout : float : between 0 and 1 : percentage of neurons we want to keep. Default : 0.75.
# network_depth : int : number of layers WARNING : factualy, there will be 2*network_depth layers. Default : 6.
# network_convolution_per_layer : list of int, length = network_depth : number of convolution per layer. Default : [1 for i in range(network_depth)].
# network_size_of_convolutions_per_layer : list of lists of int [number of layers[number_of_convolutions_per_layer]] : Describe the size of each convolution filter.
# Default : [[3 for k in range(network_convolution_per_layer[i])] for i in range(network_depth)].

# network_features_per_convolution : list of lists of int [number of layers[number_of_convolutions_per_layer[2]] : Numer of different filters that are going to be used.
# Default : [[[64,64] for k in range(network_convolution_per_layer[i])] for i in range(network_depth)]. WARNING ! network_features_per_convolution[k][1] = network_features_per_convolution[k+1][0].

# network_trainingset : string : String describing the dataset used for the training.

# %%
filename = '/config_network.json'

# %%
trainingset_name = 'data_2_classes_gen'

# %%
network_learning_rate = 0.0005
network_n_classes = 2
dropout = 0.1
network_depth = 3
network_convolution_per_layer = [2 for i in range(network_depth)]
network_size_of_convolutions_per_layer = [[3,3],[3,3],[3,3],[3,3]]#[[3 for k in range(network_convolution_per_layer[i])] for i in range(network_depth)]
network_features_per_convolution = [[[10,15],[15,20]],[[20,25],[25,30]],[[30,35],[35,40]]]

downsampling = 'maxpooling'

thresholds = [0,0.5]

weighted_cost = False

config = {
    'network_learning_rate': network_learning_rate,
    'network_n_classes': network_n_classes,
    'network_dropout': dropout,
    'network_depth': network_depth,
    'network_convolution_per_layer': network_convolution_per_layer,
    'network_size_of_convolutions_per_layer': network_size_of_convolutions_per_layer,
    'network_features_per_convolution': network_features_per_convolution,
    'network_trainingset': trainingset_name,
    'network_downsampling': downsampling,
    'network_thresholds': thresholds,
    'network_weighted_cost': weighted_cost,
    'network_batch_size': 1
}

# %%
path_training = '/Users/alzaia/Desktop/cnn_project/data_2_classes_gen/training'
# path_training = '../data/'+trainingset_name+'/training'

# %%
dir_name = time.strftime("%Y-%m-%d") + '_' + time.strftime("%H-%M-%S") 
#dir_name = 'baseline_bis'
path_model = os.path.join('../models/', dir_name)

if not os.path.exists(path_model):
    os.makedirs(path_model)
    
path_model_init = None 


# Specify here the path to the initial model if needed.

if os.path.exists(path_model+filename): # if there is already a configfile
    with open(path_model+filename, 'r') as fd:
        config_network = json.loads(fd.read())
else: # There is no config file for the moment
    with open(path_model+filename, 'w') as f:
        json.dump(config, f, indent=2)
    with open(path_model+filename, 'r') as fd:
        config_network = json.loads(fd.read())
    
################################################### Training phase ###################################################

# Note : possible values for gpu: None, '/gpu:0'. If used withing CUDA_VISIBLE_DEVICES=?, then it will use gpu number ? by default
from AxonDeepSeg.train_network import train_model
train_model(path_training, path_model, config_network,path_model_init=path_model_init, data_augmentation=['shifting'],gpu='/gpu:0', batch_size=1)
# Out:
# None
# ('Input features layer : ', 80)
# ('Input features layer : ', 60)
# ('Input features layer : ', 40)
# ('Layer: ', 0, ' Conv: ', 0, 'Features: ', [10, 15])
# ('Size:', 3)
# ('Layer: ', 0, ' Conv: ', 1, 'Features: ', [15, 20])
# ('Size:', 3)
# ('Layer: ', 1, ' Conv: ', 0, 'Features: ', [20, 25])
# ('Size:', 3)
# ('Layer: ', 1, ' Conv: ', 1, 'Features: ', [25, 30])
# ('Size:', 3)
# ('Layer: ', 2, ' Conv: ', 0, 'Features: ', [30, 35])
# ('Size:', 3)
# ('Layer: ', 2, ' Conv: ', 1, 'Features: ', [35, 40])
# ('Size:', 3)
# ('Layer: ', 0, ' Conv: ', 0, 'Features: ', [10, 15])
# ('Size:', 3)
# ('Layer: ', 0, ' Conv: ', 1, 'Features: ', [15, 20])
# ('Size:', 3)
# ('Layer: ', 1, ' Conv: ', 0, 'Features: ', [20, 25])
# ('Size:', 3)
# ('Layer: ', 1, ' Conv: ', 1, 'Features: ', [25, 30])
# ('Size:', 3)
# ('Layer: ', 2, ' Conv: ', 0, 'Features: ', [30, 35])
# ('Size:', 3)
# ('Layer: ', 2, ' Conv: ', 1, 'Features: ', [35, 40])
# ('Size:', 3)
# ('tot_param = ', 216397)
# training start
# Default cost selected
# /Users/alzaia/venv/tfnew/lib/python2.7/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# ----Scores on validation:---
# ----
#  Last epoch: 1
#  Accuracy: 0.705124;
#  Loss: 1.22055;
#
#
# ----Scores on validation:---
# ----
#  Last epoch: 2
#  Accuracy: 0.72155;
#  Loss: 0.704352;
#
#
# ----Scores on validation:---
# ----
#  Last epoch: 3
#  Accuracy: 0.732574;
#  Loss: 0.596349;
#
#
# ----Scores on validation:---
# ----
#  Last epoch: 4
#  Accuracy: 0.70931;
#  Loss: 0.601829;
#
#
# ----Scores on validation:---
# ----
#  Last epoch: 5
#  Accuracy: 0.750314;
#  Loss: 0.52435;
#
#
# ----Scores on validation:---
# ----
#  Last epoch: 6
#  Accuracy: 0.7733;
#  Loss: 0.492131;
# Model saved in file: ../models/2017-06-23_13-03-22/model.ckpt
#
#
# ----Scores on validation:---
# ----
#  Last epoch: 7
#  Accuracy: 0.746991;
#  Loss: 0.520422;
#
#
# ----Scores on validation:---
# ----
#  Last epoch: 8
#  Accuracy: 0.774287;
#  Loss: 0.487173;
#
#
# ----Scores on validation:---
# ----
#  Last epoch: 9
#  Accuracy: 0.768374;
#  Loss: 0.491281;
#
#
# ----Scores on validation:---
# ----
#  Last epoch: 10
#  Accuracy: 0.784843;
#  Loss: 0.467244;
#
#
# ----Scores on validation:---
# ----
#  Last epoch: 11
#  Accuracy: 0.798602;
#  Loss: 0.453838;
#
#
# ----Scores on validation:---
# ----
#  Last epoch: 12
#  Accuracy: 0.740691;
#  Loss: 0.519542;
#
#
# ----Scores on validation:---
# ----
#  Last epoch: 13
#  Accuracy: 0.804778;
#  Loss: 0.448733;
# Model saved in file: ../models/2017-06-23_13-03-22/model.ckpt
#
#
# ----Scores on validation:---
# ----
#  Last epoch: 14
#  Accuracy: 0.681436;
#  Loss: 0.617133;
#
#
# ----Scores on validation:---
# ----
#  Last epoch: 15
#  Accuracy: 0.814776;
#  Loss: 0.430578;
#
#
# ----Scores on validation:---
# ----
#  Last epoch: 16
#  Accuracy: 0.797503;
#  Loss: 0.443444;
#
#
# ----Scores on validation:---
# ----
#  Last epoch: 17
#  Accuracy: 0.82035;
#  Loss: 0.421168;
#
#
# ----Scores on validation:---
# ----
#  Last epoch: 18
#  Accuracy: 0.818393;
#  Loss: 0.421423;
#
#
# ----Scores on validation:---
# ----
#  Last epoch: 19
#  Accuracy: 0.773885;
#  Loss: 0.470327;
# Model saved in file: ../models/2017-06-23_13-03-22/model.ckpt
#
#
# ----Scores on validation:---
# ----
#  Last epoch: 20
#  Accuracy: 0.830482;
#  Loss: 0.406658;
#
#
# ----Scores on validation:---
# ----
#  Last epoch: 21
#  Accuracy: 0.807867;
#  Loss: 0.423955;
#
#
# ----Scores on validation:---
# ----
#  Last epoch: 22
#  Accuracy: 0.829354;
#  Loss: 0.399958;
#
#
# ----Scores on validation:---
# ----
#  Last epoch: 23
#  Accuracy: 0.841919;
#  Loss: 0.379717;
#
#
# ----Scores on validation:---
# ----
#  Last epoch: 24
#  Accuracy: 0.824553;
#  Loss: 0.403323;
#
#
# ----Scores on validation:---
# ----
#  Last epoch: 25
#  Accuracy: 0.849176;
#  Loss: 0.365883;
#
#
# ----Scores on validation:---
# ----
#  Last epoch: 26
#  Accuracy: 0.833602;
#  Loss: 0.385826;
# Model saved in file: ../models/2017-06-23_13-03-22/model.ckpt
#
#
# ----Scores on validation:---
# ----
#  Last epoch: 27
#  Accuracy: 0.824312;
#  Loss: 0.405398;
#
#
# ----Scores on validation:---
# ----
#  Last epoch: 28
#  Accuracy: 0.855881;
#  Loss: 0.35237;
#
#
# ----Scores on validation:---
# ----
#  Last epoch: 29
#  Accuracy: 0.849023;
#  Loss: 0.360993;
#
#
# ----Scores on validation:---
# ----
#  Last epoch: 30
#  Accuracy: 0.853026;
#  Loss: 0.356888;
#
#
# ----Scores on validation:---
# ----
#  Last epoch: 31
#  Accuracy: 0.863084;
#  Loss: 0.338722;
#
#
# ----Scores on validation:---
# ----
#  Last epoch: 32
#  Accuracy: 0.865639;
#  Loss: 0.335683;
# Model saved in file: ../models/2017-06-23_13-03-22/model.ckpt
#
#
# ----Scores on validation:---
# ----
#  Last epoch: 33
#  Accuracy: 0.866226;
#  Loss: 0.33499;
#
#
# ----Scores on validation:---
# ----
#  Last epoch: 34
#  Accuracy: 0.789255;
#  Loss: 0.45731;
#
#
# ----Scores on validation:---
# ----
#  Last epoch: 35
#  Accuracy: 0.844082;
#  Loss: 0.371039;
#
#
# ----Scores on validation:---
# ----
#  Last epoch: 36
#  Accuracy: 0.864901;
#  Loss: 0.333253;
#
#
# ----Scores on validation:---
# ----
#  Last epoch: 37
#  Accuracy: 0.866301;
#  Loss: 0.332182;
#
#
# ----Scores on validation:---
# ----
#  Last epoch: 38
#  Accuracy: 0.844823;
#  Loss: 0.369263;
#
#
# ----Scores on validation:---
# ----
#  Last epoch: 39
#  Accuracy: 0.873477;
#  Loss: 0.316679;
# Model saved in file: ../models/2017-06-23_13-03-22/model.ckpt
#
#
# ----Scores on validation:---
# ----
#  Last epoch: 40
#  Accuracy: 0.874713;
#  Loss: 0.314741;
#
#
# ----Scores on validation:---
# ----
#  Last epoch: 41
#  Accuracy: 0.880119;
#  Loss: 0.302848;
#
#
# ----Scores on validation:---
# ----
#  Last epoch: 42
#  Accuracy: 0.882004;
#  Loss: 0.301119;
#
#
# ----Scores on validation:---
# ----
#  Last epoch: 43
#  Accuracy: 0.885156;
#  Loss: 0.296767;
#
#
# ----Scores on validation:---
# ----
#  Last epoch: 44
#  Accuracy: 0.867988;
#  Loss: 0.324925;
#
#
# ----Scores on validation:---
# ----
#  Last epoch: 45
#  Accuracy: 0.861221;
#  Loss: 0.345355;
# Model saved in file: ../models/2017-06-23_13-03-22/model.ckpt
#
#
# ----Scores on validation:---
# ----
#  Last epoch: 46
#  Accuracy: 0.886383;
#  Loss: 0.29101;
#
#
# ----Scores on validation:---
# ----
#  Last epoch: 47
#  Accuracy: 0.885501;
#  Loss: 0.292634;
#
#
# ----Scores on validation:---
# ----
#  Last epoch: 48
#  Accuracy: 0.893413;
#  Loss: 0.276187;
#
#
# ----Scores on validation:---
# ----
#  Last epoch: 49
#  Accuracy: 0.887896;
#  Loss: 0.2853;
#
#
# ----Scores on validation:---
# ----
#  Last epoch: 50
#  Accuracy: 0.884161;
#  Loss: 0.300088;
#
#
# ----Scores on validation:---
# ----
#  Last epoch: 51
#  Accuracy: 0.891743;
#  Loss: 0.278408;
#
#
# ----Scores on validation:---
# ----
#  Last epoch: 52
#  Accuracy: 0.840939;
#  Loss: 0.387359;
# Model saved in file: ../models/2017-06-23_13-03-22/model.ckpt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-3241bf8d200e> in <module>()
#      24 # Note : possible values for gpu: None, '/gpu:0'. If used withing CUDA_VISIBLE_DEVICES=?, then it will use gpu number ? by default
#      25 from AxonDeepSeg.train_network import train_model
# ---> 26 train_model(path_training, path_model, config_network,path_model_init=path_model_init, data_augmentation=['shifting'],gpu='/gpu:0', batch_size=1)
#
# /Users/alzaia/axondeepseg/AxonDeepSeg/train_network.pyc in train_model(path_trainingset, path_model, config, path_model_init, save_trainable, data_augmentation, gpu, batch_size)
#     575                 else:
#     576                     stepcost, stepacc, _ = session.run([cost, accuracy, optimizer], feed_dict={x: batch_x, y: batch_y,
# --> 577                                                            keep_prob: dropout})
#     578                     epoch_training_loss.append(stepcost)
#     579                     epoch_training_acc.append(stepacc)
#
# /Users/alzaia/venv/tfnew/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     776     try:
#     777       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 778                          run_metadata_ptr)
#     779       if run_metadata:
#     780         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /Users/alzaia/venv/tfnew/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     980     if final_fetches or final_targets:
#     981       results = self._do_run(handle, final_targets, final_fetches,
# --> 982                              feed_dict_string, options, run_metadata)
#     983     else:
#     984       results = []
#
# /Users/alzaia/venv/tfnew/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1030     if handle is None:
#    1031       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1032                            target_list, options, run_metadata)
#    1033     else:
#    1034       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /Users/alzaia/venv/tfnew/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1037   def _do_call(self, fn, *args):
#    1038     try:
# -> 1039       return fn(*args)
#    1040     except errors.OpError as e:
#    1041       message = compat.as_text(e.message)
#
# /Users/alzaia/venv/tfnew/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1019         return tf_session.TF_Run(session, options,
#    1020                                  feed_dict, fetch_list, target_list,
# -> 1021                                  status, run_metadata)
#    1022
#    1023     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
