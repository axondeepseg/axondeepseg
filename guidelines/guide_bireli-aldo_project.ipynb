# %%
import json
import os
import time

# %%
# Description du fichier config :
# network_learning_rate : float : No idea, but certainly linked to the back propagation ? Default : 0.0005.
# network_n_classes : int : number of labels in the output. Default : 2.
# dropout : float : between 0 and 1 : percentage of neurons we want to keep. Default : 0.75.
# network_depth : int : number of layers WARNING : factualy, there will be 2*network_depth layers. Default : 6.
# network_convolution_per_layer : list of int, length = network_depth : number of convolution per layer. Default : [1 for i in range(network_depth)].
# network_size_of_convolutions_per_layer : list of lists of int [number of layers[number_of_convolutions_per_layer]] : Describe the size of each convolution filter.
# Default : [[3 for k in range(network_convolution_per_layer[i])] for i in range(network_depth)].

# network_features_per_convolution : list of lists of int [number of layers[number_of_convolutions_per_layer[2]] : Numer of different filters that are going to be used.
# Default : [[[64,64] for k in range(network_convolution_per_layer[i])] for i in range(network_depth)]. WARNING ! network_features_per_convolution[k][1] = network_features_per_convolution[k+1][0].

# network_trainingset : string : String describing the dataset used for the training.

# %%
filename = '/config_network.json'

# %%
trainingset_name = 'data_2_classes_gen'

# %%
network_learning_rate = 0.0005
network_n_classes = 2
dropout = 0.5
network_depth = 3
network_convolution_per_layer = [2 for i in range(network_depth)]
network_size_of_convolutions_per_layer = [[3,3],[3,3],[3,3],[3,3]]#[[3 for k in range(network_convolution_per_layer[i])] for i in range(network_depth)]
network_features_per_convolution = [[[10,15],[15,20]],[[20,25],[25,30]],[[30,35],[35,40]]]

downsampling = 'maxpooling'

thresholds = [0,0.5]

weighted_cost = False

config = {
    'network_learning_rate': network_learning_rate,
    'network_n_classes': network_n_classes,
    'network_dropout': dropout,
    'network_depth': network_depth,
    'network_convolution_per_layer': network_convolution_per_layer,
    'network_size_of_convolutions_per_layer': network_size_of_convolutions_per_layer,
    'network_features_per_convolution': network_features_per_convolution,
    'network_trainingset': trainingset_name,
    'network_downsampling': downsampling,
    'network_thresholds': thresholds,
    'network_weighted_cost': weighted_cost
}

# %%
path_training = '/Users/alzaia/Desktop/cnn_project/data_2_classes_gen/training'
# path_training = '../data/'+trainingset_name+'/training'

# %%
dir_name = time.strftime("%Y-%m-%d") + '_' + time.strftime("%H-%M-%S") 
#dir_name = 'baseline_bis'
path_model = os.path.join('../models/', dir_name)

if not os.path.exists(path_model):
    os.makedirs(path_model)
    
path_model_init = None 


# Specify here the path to the initial model if needed.

if os.path.exists(path_model+filename): # if there is already a configfile
    with open(path_model+filename, 'r') as fd:
        config_network = json.loads(fd.read())
else: # There is no config file for the moment
    with open(path_model+filename, 'w') as f:
        json.dump(config, f, indent=2)
    with open(path_model+filename, 'r') as fd:
        config_network = json.loads(fd.read())
    
################################################### Training phase ###################################################

# Note : possible values for gpu: None, '/gpu:0'. If used withing CUDA_VISIBLE_DEVICES=?, then it will use gpu number ? by default
from AxonDeepSeg.train_network import train_model
train_model(path_training, path_model, config_network,path_model_init=path_model_init,gpu='/gpu:0', augmented_data=True)
# Out:
# ('Input features layer : ', 80)
# ('Input features layer : ', 60)
# ('Input features layer : ', 40)
# ('Layer: ', 0, ' Conv: ', 0, 'Features: ', [10, 15])
# ('Size:', 3)
# ('Layer: ', 0, ' Conv: ', 1, 'Features: ', [15, 20])
# ('Size:', 3)
# ('Layer: ', 1, ' Conv: ', 0, 'Features: ', [20, 25])
# ('Size:', 3)
# ('Layer: ', 1, ' Conv: ', 1, 'Features: ', [25, 30])
# ('Size:', 3)
# ('Layer: ', 2, ' Conv: ', 0, 'Features: ', [30, 35])
# ('Size:', 3)
# ('Layer: ', 2, ' Conv: ', 1, 'Features: ', [35, 40])
# ('Size:', 3)
# ('Layer: ', 0, ' Conv: ', 0, 'Features: ', [10, 15])
# ('Size:', 3)
# ('Layer: ', 0, ' Conv: ', 1, 'Features: ', [15, 20])
# ('Size:', 3)
# ('Layer: ', 1, ' Conv: ', 0, 'Features: ', [20, 25])
# ('Size:', 3)
# ('Layer: ', 1, ' Conv: ', 1, 'Features: ', [25, 30])
# ('Size:', 3)
# ('Layer: ', 2, ' Conv: ', 0, 'Features: ', [30, 35])
# ('Size:', 3)
# ('Layer: ', 2, ' Conv: ', 1, 'Features: ', [35, 40])
# ('Size:', 3)
# ('tot_param = ', 216397)
# training start
# Default cost selected
# --
# Accuracy on patch0: 0.741272
# Loss on patch0: 0.455449
# --
# Accuracy on patch1: 0.746216
# Loss on patch1: 0.433067
# --
# Accuracy on patch2: 0.72998
# Loss on patch2: 0.514934
# --
# Accuracy on patch3: 0.739609
# Loss on patch3: 0.533514
# --
# Accuracy on patch4: 0.737366
# Loss on patch4: 0.48573
# --
# Accuracy on patch5: 0.741852
# Loss on patch5: 0.500099
# --
# Accuracy on patch6: 0.614685
# Loss on patch6: 0.658873
# --
# Accuracy on patch7: 0.628586
# Loss on patch7: 0.642531
# --
# Accuracy on patch8: 0.722382
# Loss on patch8: 0.548943
# --
# Accuracy on patch9: 0.779099
# Loss on patch9: 0.405665
# --
# Accuracy on patch10: 0.732132
# Loss on patch10: 0.502656
# --
# Accuracy on patch11: 0.614334
# Loss on patch11: 0.66593
# --
# Accuracy on patch12: 0.726242
# Loss on patch12: 0.579286
# --
# Accuracy on patch13: 0.720749
# Loss on patch13: 0.573134
# --
# Accuracy on patch14: 0.741089
# Loss on patch14: 0.41991
# --
# Accuracy on patch15: 0.750748
# Loss on patch15: 0.405902
# --
# Accuracy on patch16: 0.757004
# Loss on patch16: 0.422843
# --
# Accuracy on patch17: 0.751129
# Loss on patch17: 0.500138
# --
# Accuracy on patch18: 0.741547
# Loss on patch18: 0.41216
# --
# Accuracy on patch19: 0.757828
# Loss on patch19: 0.394145
# --
# Accuracy on patch20: 0.765778
# Loss on patch20: 0.445192
# --
# Accuracy on patch21: 0.754776
# Loss on patch21: 0.440675
# --
# Accuracy on patch22: 0.72493
# Loss on patch22: 0.462972
#
#
# ----Scores on test:---
# ----
#  Last epoch: 1
#  Accuracy: 0.726927;
#  Loss: 0.495815;
# --
# Accuracy on patch0: 0.777496
# Loss on patch0: 0.408627
# --
# Accuracy on patch1: 0.788025
# Loss on patch1: 0.352011
# --
# Accuracy on patch2: 0.755997
# Loss on patch2: 0.455437
# --
# Accuracy on patch3: 0.768967
# Loss on patch3: 0.470281
# --
# Accuracy on patch4: 0.779572
# Loss on patch4: 0.428483
# --
# Accuracy on patch5: 0.778519
# Loss on patch5: 0.442512
# --
# Accuracy on patch6: 0.655289
# Loss on patch6: 0.593703
# --
# Accuracy on patch7: 0.677124
# Loss on patch7: 0.573499
# --
# Accuracy on patch8: 0.744934
# Loss on patch8: 0.490781
# --
# Accuracy on patch9: 0.819275
# Loss on patch9: 0.345205
# --
# Accuracy on patch10: 0.767563
# Loss on patch10: 0.42595
# --
# Accuracy on patch11: 0.658264
# Loss on patch11: 0.601274
# --
# Accuracy on patch12: 0.75293
# Loss on patch12: 0.491492
# --
# Accuracy on patch13: 0.736176
# Loss on patch13: 0.505706
# --
# Accuracy on patch14: 0.787231
# Loss on patch14: 0.386606
# --
# Accuracy on patch15: 0.783005
# Loss on patch15: 0.342545
# --
# Accuracy on patch16: 0.807999
# Loss on patch16: 0.370197
# --
# Accuracy on patch17: 0.771408
# Loss on patch17: 0.409351
# --
# Accuracy on patch18: 0.78476
# Loss on patch18: 0.36004
# --
# Accuracy on patch19: 0.795761
# Loss on patch19: 0.347361
# --
# Accuracy on patch20: 0.800735
# Loss on patch20: 0.384825
# --
# Accuracy on patch21: 0.784683
# Loss on patch21: 0.408628
# --
# Accuracy on patch22: 0.771606
# Loss on patch22: 0.396208
#
#
# ----Scores on test:---
# ----
#  Last epoch: 2
#  Accuracy: 0.762927;
#  Loss: 0.434379;
# --
# Accuracy on patch0: 0.733673
# Loss on patch0: 0.190359
# --
# Accuracy on patch1: 0.813217
# Loss on patch1: 0.158922
# --
# Accuracy on patch2: 0.720886
# Loss on patch2: 0.217353
# --
# Accuracy on patch3: 0.753098
# Loss on patch3: 0.225016
# --
# Accuracy on patch4: 0.788132
# Loss on patch4: 0.198347
# --
# Accuracy on patch5: 0.790756
# Loss on patch5: 0.212326
# --
# Accuracy on patch6: 0.557846
# Loss on patch6: 0.306984
# --
# Accuracy on patch7: 0.583755
# Loss on patch7: 0.287858
# --
# Accuracy on patch8: 0.757309
# Loss on patch8: 0.231978
# --
# Accuracy on patch9: 0.794418
# Loss on patch9: 0.160813
# --
# Accuracy on patch10: 0.81723
# Loss on patch10: 0.193082
# --
# Accuracy on patch11: 0.56456
# Loss on patch11: 0.30757
# --
# Accuracy on patch12: 0.769043
# Loss on patch12: 0.236906
# --
# Accuracy on patch13: 0.69426
# Loss on patch13: 0.244898
# --
# Accuracy on patch14: 0.720444
# Loss on patch14: 0.187866
# --
# Accuracy on patch15: 0.764542
# Loss on patch15: 0.151821
# --
# Accuracy on patch16: 0.756729
# Loss on patch16: 0.180603
# --
# Accuracy on patch17: 0.81131
# Loss on patch17: 0.190307
# --
# Accuracy on patch18: 0.729874
# Loss on patch18: 0.170167
# --
# Accuracy on patch19: 0.760101
# Loss on patch19: 0.149185
# --
# Accuracy on patch20: 0.768753
# Loss on patch20: 0.173494
# --
# Accuracy on patch21: 0.775269
# Loss on patch21: 0.192436
# --
# Accuracy on patch22: 0.714615
# Loss on patch22: 0.18597
#
#
# ----Scores on test:---
# ----
#  Last epoch: 3
#  Accuracy: 0.736514;
#  Loss: 0.206707;
# Model saved in file: ../models/2017-06-16_15-30-59/model.ckpt
# --
# Accuracy on patch0: 0.754944
# Loss on patch0: 0.186587
# --
# Accuracy on patch1: 0.828812
# Loss on patch1: 0.150905
# --
# Accuracy on patch2: 0.739914
# Loss on patch2: 0.209023
# --
# Accuracy on patch3: 0.782379
# Loss on patch3: 0.213562
# --
# Accuracy on patch4: 0.812485
# Loss on patch4: 0.185573
# --
# Accuracy on patch5: 0.808136
# Loss on patch5: 0.200962
# --
# Accuracy on patch6: 0.570663
# Loss on patch6: 0.292651
# --
# Accuracy on patch7: 0.59729
# Loss on patch7: 0.277532
# --
# Accuracy on patch8: 0.780838
# Loss on patch8: 0.218084
# --
# Accuracy on patch9: 0.826416
# Loss on patch9: 0.145767
# --
# Accuracy on patch10: 0.824585
# Loss on patch10: 0.192286
# --
# Accuracy on patch11: 0.578217
# Loss on patch11: 0.296112
# --
# Accuracy on patch12: 0.786758
# Loss on patch12: 0.222526
# --
# Accuracy on patch13: 0.710709
# Loss on patch13: 0.243139
# --
# Accuracy on patch14: 0.751007
# Loss on patch14: 0.174726
# --
# Accuracy on patch15: 0.78717
# Loss on patch15: 0.140506
# --
# Accuracy on patch16: 0.785751
# Loss on patch16: 0.169623
# --
# Accuracy on patch17: 0.827957
# Loss on patch17: 0.191708
# --
# Accuracy on patch18: 0.753494
# Loss on patch18: 0.163486
# --
# Accuracy on patch19: 0.787354
# Loss on patch19: 0.140821
# --
# Accuracy on patch20: 0.787842
# Loss on patch20: 0.173692
# --
# Accuracy on patch21: 0.799698
# Loss on patch21: 0.182818
# --
# Accuracy on patch22: 0.739334
# Loss on patch22: 0.179094
#
#
# ----Scores on test:---
# ----
#  Last epoch: 4
#  Accuracy: 0.757468;
#  Loss: 0.197878;
# --
# Accuracy on patch0: 0.740768
# Loss on patch0: 0.151335
# --
# Accuracy on patch1: 0.815125
# Loss on patch1: 0.119516
# --
# Accuracy on patch2: 0.731644
# Loss on patch2: 0.164567
# --
# Accuracy on patch3: 0.775513
# Loss on patch3: 0.17058
# --
# Accuracy on patch4: 0.803848
# Loss on patch4: 0.14423
# --
# Accuracy on patch5: 0.806793
# Loss on patch5: 0.157314
# --
# Accuracy on patch6: 0.555206
# Loss on patch6: 0.234742
# --
# Accuracy on patch7: 0.57782
# Loss on patch7: 0.221243
# --
# Accuracy on patch8: 0.779938
# Loss on patch8: 0.16843
# --
# Accuracy on patch9: 0.803574
# Loss on patch9: 0.117974
# --
# Accuracy on patch10: 0.824585
# Loss on patch10: 0.150812
# --
# Accuracy on patch11: 0.56485
# Loss on patch11: 0.234038
# --
# Accuracy on patch12: 0.784164
# Loss on patch12: 0.175332
# --
# Accuracy on patch13: 0.694397
# Loss on patch13: 0.200624
# --
# Accuracy on patch14: 0.732147
# Loss on patch14: 0.135587
# --
# Accuracy on patch15: 0.767822
# Loss on patch15: 0.113293
# --
# Accuracy on patch16: 0.767151
# Loss on patch16: 0.132517
# --
# Accuracy on patch17: 0.838989
# Loss on patch17: 0.149384
# --
# Accuracy on patch18: 0.730499
# Loss on patch18: 0.132815
# --
# Accuracy on patch19: 0.769073
# Loss on patch19: 0.116208
# --
# Accuracy on patch20: 0.770477
# Loss on patch20: 0.13916
# --
# Accuracy on patch21: 0.789597
# Loss on patch21: 0.14174
# --
# Accuracy on patch22: 0.720078
# Loss on patch22: 0.144896
#
#
# ----Scores on test:---
# ----
#  Last epoch: 5
#  Accuracy: 0.745394;
#  Loss: 0.157232;
# --
# Accuracy on patch0: 0.772003
# Loss on patch0: 0.158838
# --
# Accuracy on patch1: 0.849228
# Loss on patch1: 0.117416
# --
# Accuracy on patch2: 0.758057
# Loss on patch2: 0.174171
# --
# Accuracy on patch3: 0.800812
# Loss on patch3: 0.187486
# --
# Accuracy on patch4: 0.834564
# Loss on patch4: 0.149912
# --
# Accuracy on patch5: 0.833908
# Loss on patch5: 0.161699
# --
# Accuracy on patch6: 0.576035
# Loss on patch6: 0.272096
# --
# Accuracy on patch7: 0.60733
# Loss on patch7: 0.252878
# --
# Accuracy on patch8: 0.80394
# Loss on patch8: 0.180971
# --
# Accuracy on patch9: 0.828171
# Loss on patch9: 0.122093
# --
# Accuracy on patch10: 0.848206
# Loss on patch10: 0.148551
# --
# Accuracy on patch11: 0.590714
# Loss on patch11: 0.273376
# --
# Accuracy on patch12: 0.814331
# Loss on patch12: 0.186544
# --
# Accuracy on patch13: 0.720474
# Loss on patch13: 0.2178
# --
# Accuracy on patch14: 0.760101
# Loss on patch14: 0.153493
# --
# Accuracy on patch15: 0.804398
# Loss on patch15: 0.115443
# --
# Accuracy on patch16: 0.795151
# Loss on patch16: 0.144319
# --
# Accuracy on patch17: 0.855164
# Loss on patch17: 0.143434
# --
# Accuracy on patch18: 0.753967
# Loss on patch18: 0.142331
# --
# Accuracy on patch19: 0.812347
# Loss on patch19: 0.118392
# --
# Accuracy on patch20: 0.794312
# Loss on patch20: 0.145368
# --
# Accuracy on patch21: 0.817429
# Loss on patch21: 0.14891
# --
# Accuracy on patch22: 0.750275
# Loss on patch22: 0.156286
#
#
# ----Scores on test:---
# ----
#  Last epoch: 6
#  Accuracy: 0.773083;
#  Loss: 0.168339;
# Model saved in file: ../models/2017-06-16_15-30-59/model.ckpt
# --
# Accuracy on patch0: 0.819595
# Loss on patch0: 0.17817
# --
# Accuracy on patch1: 0.830627
# Loss on patch1: 0.162364
# --
# Accuracy on patch2: 0.802887
# Loss on patch2: 0.191023
# --
# Accuracy on patch3: 0.838837
# Loss on patch3: 0.192337
# --
# Accuracy on patch4: 0.858734
# Loss on patch4: 0.160385
# --
# Accuracy on patch5: 0.848572
# Loss on patch5: 0.181827
# --
# Accuracy on patch6: 0.654739
# Loss on patch6: 0.255752
# --
# Accuracy on patch7: 0.67897
# Loss on patch7: 0.238186
# --
# Accuracy on patch8: 0.844818
# Loss on patch8: 0.187721
# --
# Accuracy on patch9: 0.878967
# Loss on patch9: 0.123943
# --
# Accuracy on patch10: 0.824905
# Loss on patch10: 0.216934
# --
# Accuracy on patch11: 0.660583
# Loss on patch11: 0.257693
# --
# Accuracy on patch12: 0.830887
# Loss on patch12: 0.20312
# --
# Accuracy on patch13: 0.785629
# Loss on patch13: 0.24395
# --
# Accuracy on patch14: 0.823792
# Loss on patch14: 0.148743
# --
# Accuracy on patch15: 0.835968
# Loss on patch15: 0.133072
# --
# Accuracy on patch16: 0.849686
# Loss on patch16: 0.143458
# --
# Accuracy on patch17: 0.846054
# Loss on patch17: 0.216524
# --
# Accuracy on patch18: 0.819855
# Loss on patch18: 0.15509
# --
# Accuracy on patch19: 0.842285
# Loss on patch19: 0.132219
# --
# Accuracy on patch20: 0.833527
# Loss on patch20: 0.173347
# --
# Accuracy on patch21: 0.846054
# Loss on patch21: 0.155913
# --
# Accuracy on patch22: 0.804947
# Loss on patch22: 0.173105
#
#
# ----Scores on test:---
# ----
#  Last epoch: 7
#  Accuracy: 0.811344;
#  Loss: 0.18369;
# --
# Accuracy on patch0: 0.80986
# Loss on patch0: 0.155385
# --
# Accuracy on patch1: 0.85434
# Loss on patch1: 0.106751
# --
# Accuracy on patch2: 0.790939
# Loss on patch2: 0.158882
# --
# Accuracy on patch3: 0.840698
# Loss on patch3: 0.166443
# --
# Accuracy on patch4: 0.86055
# Loss on patch4: 0.128417
# --
# Accuracy on patch5: 0.852356
# Loss on patch5: 0.144632
# --
# Accuracy on patch6: 0.627121
# Loss on patch6: 0.24408
# --
# Accuracy on patch7: 0.655121
# Loss on patch7: 0.224292
# --
# Accuracy on patch8: 0.84314
# Loss on patch8: 0.155477
# --
# Accuracy on patch9: 0.868073
# Loss on patch9: 0.104299
# --
# Accuracy on patch10: 0.855072
# Loss on patch10: 0.148366
# --
# Accuracy on patch11: 0.640793
# Loss on patch11: 0.246494
# --
# Accuracy on patch12: 0.838959
# Loss on patch12: 0.164311
# --
# Accuracy on patch13: 0.772354
# Loss on patch13: 0.2114
# --
# Accuracy on patch14: 0.805237
# Loss on patch14: 0.134011
# --
# Accuracy on patch15: 0.834045
# Loss on patch15: 0.107144
# --
# Accuracy on patch16: 0.838852
# Loss on patch16: 0.124893
# --
# Accuracy on patch17: 0.884766
# Loss on patch17: 0.139362
# --
# Accuracy on patch18: 0.794296
# Loss on patch18: 0.136323
# --
# Accuracy on patch19: 0.843719
# Loss on patch19: 0.112728
# --
# Accuracy on patch20: 0.813751
# Loss on patch20: 0.149296
# --
# Accuracy on patch21: 0.842804
# Loss on patch21: 0.129982
# --
# Accuracy on patch22: 0.786087
# Loss on patch22: 0.150796
#
#
# ----Scores on test:---
# ----
#  Last epoch: 8
#  Accuracy: 0.806649;
#  Loss: 0.154077;
# --
# Accuracy on patch0: 0.831833
# Loss on patch0: 0.188821
# --
# Accuracy on patch1: 0.884949
# Loss on patch1: 0.140482
# --
# Accuracy on patch2: 0.81781
# Loss on patch2: 0.199518
# --
# Accuracy on patch3: 0.851105
# Loss on patch3: 0.220309
# --
# Accuracy on patch4: 0.876282
# Loss on patch4: 0.172536
# --
# Accuracy on patch5: 0.871765
# Loss on patch5: 0.184967
# --
# Accuracy on patch6: 0.665512
# Loss on patch6: 0.30362
# --
# Accuracy on patch7: 0.690674
# Loss on patch7: 0.282425
# --
# Accuracy on patch8: 0.850021
# Loss on patch8: 0.208065
# --
# Accuracy on patch9: 0.883057
# Loss on patch9: 0.140111
# --
# Accuracy on patch10: 0.87825
# Loss on patch10: 0.173034
# --
# Accuracy on patch11: 0.678635
# Loss on patch11: 0.307167
# --
# Accuracy on patch12: 0.854019
# Loss on patch12: 0.217874
# --
# Accuracy on patch13: 0.797577
# Loss on patch13: 0.253905
# --
# Accuracy on patch14: 0.831192
# Loss on patch14: 0.185081
# --
# Accuracy on patch15: 0.864929
# Loss on patch15: 0.13679
# --
# Accuracy on patch16: 0.858932
# Loss on patch16: 0.173692
# --
# Accuracy on patch17: 0.896378
# Loss on patch17: 0.156666
# --
# Accuracy on patch18: 0.825638
# Loss on patch18: 0.168646
# --
# Accuracy on patch19: 0.873657
# Loss on patch19: 0.145382
# --
# Accuracy on patch20: 0.842422
# Loss on patch20: 0.177084
# --
# Accuracy on patch21: 0.861252
# Loss on patch21: 0.171978
# --
# Accuracy on patch22: 0.820358
# Loss on patch22: 0.18765
#
#
# ----Scores on test:---
# ----
#  Last epoch: 9
#  Accuracy: 0.830706;
#  Loss: 0.19547;
# Model saved in file: ../models/2017-06-16_15-30-59/model.ckpt
# --
# Accuracy on patch0: 0.843796
# Loss on patch0: 0.194817
# --
# Accuracy on patch1: 0.886642
# Loss on patch1: 0.137234
# --
# Accuracy on patch2: 0.830902
# Loss on patch2: 0.200051
# --
# Accuracy on patch3: 0.863892
# Loss on patch3: 0.221756
# --
# Accuracy on patch4: 0.885422
# Loss on patch4: 0.171307
# --
# Accuracy on patch5: 0.884125
# Loss on patch5: 0.184088
# --
# Accuracy on patch6: 0.697861
# Loss on patch6: 0.314335
# --
# Accuracy on patch7: 0.719543
# Loss on patch7: 0.287909
# --
# Accuracy on patch8: 0.866394
# Loss on patch8: 0.205461
# --
# Accuracy on patch9: 0.894852
# Loss on patch9: 0.140952
# --
# Accuracy on patch10: 0.88298
# Loss on patch10: 0.171458
# --
# Accuracy on patch11: 0.707031
# Loss on patch11: 0.314813
# --
# Accuracy on patch12: 0.8685
# Loss on patch12: 0.213214
# --
# Accuracy on patch13: 0.819275
# Loss on patch13: 0.261459
# --
# Accuracy on patch14: 0.851746
# Loss on patch14: 0.188236
# --
# Accuracy on patch15: 0.886673
# Loss on patch15: 0.137528
# --
# Accuracy on patch16: 0.872604
# Loss on patch16: 0.171442
# --
# Accuracy on patch17: 0.901917
# Loss on patch17: 0.15411
# --
# Accuracy on patch18: 0.842331
# Loss on patch18: 0.175149
# --
# Accuracy on patch19: 0.886826
# Loss on patch19: 0.142507
# --
# Accuracy on patch20: 0.855225
# Loss on patch20: 0.180364
# --
# Accuracy on patch21: 0.87439
# Loss on patch21: 0.170689
# --
# Accuracy on patch22: 0.833237
# Loss on patch22: 0.191614
#
#
# ----Scores on test:---
# ----
#  Last epoch: 10
#  Accuracy: 0.84592;
#  Loss: 0.196978;
# --
# Accuracy on patch0: 0.858688
# Loss on patch0: 0.215419
# --
# Accuracy on patch1: 0.888168
# Loss on patch1: 0.157886
# --
# Accuracy on patch2: 0.865646
# Loss on patch2: 0.218757
# --
# Accuracy on patch3: 0.869568
# Loss on patch3: 0.230452
# --
# Accuracy on patch4: 0.890579
# Loss on patch4: 0.183932
# --
# Accuracy on patch5: 0.883743
# Loss on patch5: 0.202666
# --
# Accuracy on patch6: 0.732712
# Loss on patch6: 0.310035
# --
# Accuracy on patch7: 0.750244
# Loss on patch7: 0.284375
# --
# Accuracy on patch8: 0.88063
# Loss on patch8: 0.214893
# --
# Accuracy on patch9: 0.908829
# Loss on patch9: 0.149986
# --
# Accuracy on patch10: 0.879044
# Loss on patch10: 0.208418
# --
# Accuracy on patch11: 0.738998
# Loss on patch11: 0.305981
# --
# Accuracy on patch12: 0.871475
# Loss on patch12: 0.228674
# --
# Accuracy on patch13: 0.828781
# Loss on patch13: 0.284306
# --
# Accuracy on patch14: 0.870926
# Loss on patch14: 0.187324
# --
# Accuracy on patch15: 0.888229
# Loss on patch15: 0.146191
# --
# Accuracy on patch16: 0.883102
# Loss on patch16: 0.175848
# --
# Accuracy on patch17: 0.890854
# Loss on patch17: 0.193786
# --
# Accuracy on patch18: 0.870331
# Loss on patch18: 0.188922
# --
# Accuracy on patch19: 0.891251
# Loss on patch19: 0.150759
# --
# Accuracy on patch20: 0.871704
# Loss on patch20: 0.202282
# --
# Accuracy on patch21: 0.882339
# Loss on patch21: 0.179921
# --
# Accuracy on patch22: 0.853836
# Loss on patch22: 0.202298
#
#
# ----Scores on test:---
# ----
#  Last epoch: 11
#  Accuracy: 0.858682;
#  Loss: 0.2097;
# --
# Accuracy on patch0: 0.863556
# Loss on patch0: 0.192887
# --
# Accuracy on patch1: 0.885132
# Loss on patch1: 0.143208
# --
# Accuracy on patch2: 0.873734
# Loss on patch2: 0.185309
# --
# Accuracy on patch3: 0.86937
# Loss on patch3: 0.209384
# --
# Accuracy on patch4: 0.891342
# Loss on patch4: 0.163154
# --
# Accuracy on patch5: 0.886078
# Loss on patch5: 0.178076
# --
# Accuracy on patch6: 0.763901
# Loss on patch6: 0.261974
# --
# Accuracy on patch7: 0.775345
# Loss on patch7: 0.240326
# --
# Accuracy on patch8: 0.886063
# Loss on patch8: 0.185854
# --
# Accuracy on patch9: 0.906952
# Loss on patch9: 0.129734
# --
# Accuracy on patch10: 0.882431
# Loss on patch10: 0.179762
# --
# Accuracy on patch11: 0.76976
# Loss on patch11: 0.260185
# --
# Accuracy on patch12: 0.872635
# Loss on patch12: 0.210901
# --
# Accuracy on patch13: 0.841156
# Loss on patch13: 0.244263
# --
# Accuracy on patch14: 0.870468
# Loss on patch14: 0.165364
# --
# Accuracy on patch15: 0.886566
# Loss on patch15: 0.13414
# --
# Accuracy on patch16: 0.885773
# Loss on patch16: 0.15694
# --
# Accuracy on patch17: 0.886139
# Loss on patch17: 0.175151
# --
# Accuracy on patch18: 0.876205
# Loss on patch18: 0.164766
# --
# Accuracy on patch19: 0.886703
# Loss on patch19: 0.137444
# --
# Accuracy on patch20: 0.875488
# Loss on patch20: 0.176434
# --
# Accuracy on patch21: 0.886047
# Loss on patch21: 0.15672
# --
# Accuracy on patch22: 0.863388
# Loss on patch22: 0.177992
#
#
# ----Scores on test:---
# ----
#  Last epoch: 12
#  Accuracy: 0.864532;
#  Loss: 0.183912;
# Model saved in file: ../models/2017-06-16_15-30-59/model.ckpt
# --
# Accuracy on patch0: 0.823761
# Loss on patch0: 0.117141
# --
# Accuracy on patch1: 0.866135
# Loss on patch1: 0.0731113
# --
# Accuracy on patch2: 0.814926
# Loss on patch2: 0.116973
# --
# Accuracy on patch3: 0.842804
# Loss on patch3: 0.13279
# --
# Accuracy on patch4: 0.861313
# Loss on patch4: 0.0940121
# --
# Accuracy on patch5: 0.874573
# Loss on patch5: 0.101628
# --
# Accuracy on patch6: 0.651703
# Loss on patch6: 0.171733
# --
# Accuracy on patch7: 0.672928
# Loss on patch7: 0.156135
# --
# Accuracy on patch8: 0.852219
# Loss on patch8: 0.115033
# --
# Accuracy on patch9: 0.853271
# Loss on patch9: 0.0754403
# --
# Accuracy on patch10: 0.859512
# Loss on patch10: 0.0910756
# --
# Accuracy on patch11: 0.667923
# Loss on patch11: 0.168916
# --
# Accuracy on patch12: 0.864624
# Loss on patch12: 0.123727
# --
# Accuracy on patch13: 0.796631
# Loss on patch13: 0.148261
# --
# Accuracy on patch14: 0.796936
# Loss on patch14: 0.105156
# --
# Accuracy on patch15: 0.840408
# Loss on patch15: 0.0704783
# --
# Accuracy on patch16: 0.827698
# Loss on patch16: 0.0999447
# --
# Accuracy on patch17: 0.874222
# Loss on patch17: 0.0810471
# --
# Accuracy on patch18: 0.793411
# Loss on patch18: 0.1073
# --
# Accuracy on patch19: 0.849594
# Loss on patch19: 0.0752866
# --
# Accuracy on patch20: 0.818436
# Loss on patch20: 0.104384
# --
# Accuracy on patch21: 0.844498
# Loss on patch21: 0.097217
# --
# Accuracy on patch22: 0.800156
# Loss on patch22: 0.109701
#
#
# ----Scores on test:---
# ----
#  Last epoch: 13
#  Accuracy: 0.815117;
#  Loss: 0.110282;
# --
# Accuracy on patch0: 0.856491
# Loss on patch0: 0.153422
# --
# Accuracy on patch1: 0.894852
# Loss on patch1: 0.0892285
# --
# Accuracy on patch2: 0.854202
# Loss on patch2: 0.143836
# --
# Accuracy on patch3: 0.870285
# Loss on patch3: 0.15262
# --
# Accuracy on patch4: 0.889465
# Loss on patch4: 0.109415
# --
# Accuracy on patch5: 0.892624
# Loss on patch5: 0.123443
# --
# Accuracy on patch6: 0.714081
# Loss on patch6: 0.208044
# --
# Accuracy on patch7: 0.722656
# Loss on patch7: 0.190206
# --
# Accuracy on patch8: 0.883652
# Loss on patch8: 0.133959
# --
# Accuracy on patch9: 0.893173
# Loss on patch9: 0.0897662
# --
# Accuracy on patch10: 0.885406
# Loss on patch10: 0.112051
# --
# Accuracy on patch11: 0.722656
# Loss on patch11: 0.206093
# --
# Accuracy on patch12: 0.875931
# Loss on patch12: 0.154132
# --
# Accuracy on patch13: 0.83844
# Loss on patch13: 0.19199
# --
# Accuracy on patch14: 0.857056
# Loss on patch14: 0.119037
# --
# Accuracy on patch15: 0.877365
# Loss on patch15: 0.0849321
# --
# Accuracy on patch16: 0.88205
# Loss on patch16: 0.113264
# --
# Accuracy on patch17: 0.906189
# Loss on patch17: 0.103109
# --
# Accuracy on patch18: 0.854691
# Loss on patch18: 0.130653
# --
# Accuracy on patch19: 0.873337
# Loss on patch19: 0.0886992
# --
# Accuracy on patch20: 0.860458
# Loss on patch20: 0.136526
# --
# Accuracy on patch21: 0.874496
# Loss on patch21: 0.110655
# --
# Accuracy on patch22: 0.845474
# Loss on patch22: 0.137256
#
#
# ----Scores on test:---
# ----
#  Last epoch: 14
#  Accuracy: 0.853262;
#  Loss: 0.134015;
# --
# Accuracy on patch0: 0.867645
# Loss on patch0: 0.204588
# --
# Accuracy on patch1: 0.889069
# Loss on patch1: 0.136995
# --
# Accuracy on patch2: 0.881088
# Loss on patch2: 0.195251
# --
# Accuracy on patch3: 0.87944
# Loss on patch3: 0.200356
# --
# Accuracy on patch4: 0.900955
# Loss on patch4: 0.150239
# --
# Accuracy on patch5: 0.899704
# Loss on patch5: 0.165864
# --
# Accuracy on patch6: 0.787018
# Loss on patch6: 0.265903
# --
# Accuracy on patch7: 0.80101
# Loss on patch7: 0.241043
# --
# Accuracy on patch8: 0.903702
# Loss on patch8: 0.170751
# --
# Accuracy on patch9: 0.911194
# Loss on patch9: 0.120907
# --
# Accuracy on patch10: 0.893143
# Loss on patch10: 0.162827
# --
# Accuracy on patch11: 0.789154
# Loss on patch11: 0.263534
# --
# Accuracy on patch12: 0.88089
# Loss on patch12: 0.205894
# --
# Accuracy on patch13: 0.849991
# Loss on patch13: 0.245153
# --
# Accuracy on patch14: 0.881119
# Loss on patch14: 0.156244
# --
# Accuracy on patch15: 0.896591
# Loss on patch15: 0.119519
# --
# Accuracy on patch16: 0.898132
# Loss on patch16: 0.156062
# --
# Accuracy on patch17: 0.907425
# Loss on patch17: 0.132885
# --
# Accuracy on patch18: 0.880676
# Loss on patch18: 0.173914
# --
# Accuracy on patch19: 0.898621
# Loss on patch19: 0.124592
# --
# Accuracy on patch20: 0.879868
# Loss on patch20: 0.181888
# --
# Accuracy on patch21: 0.890701
# Loss on patch21: 0.148077
# --
# Accuracy on patch22: 0.864487
# Loss on patch22: 0.193196
#
#
# ----Scores on test:---
# ----
#  Last epoch: 15
#  Accuracy: 0.875288;
#  Loss: 0.178943;
# Model saved in file: ../models/2017-06-16_15-30-59/model.ckpt
# --
# Accuracy on patch0: 0.871048
# Loss on patch0: 0.160312
# --
# Accuracy on patch1: 0.901917
# Loss on patch1: 0.0991817
# --
# Accuracy on patch2: 0.887909
# Loss on patch2: 0.152506
# --
# Accuracy on patch3: 0.876541
# Loss on patch3: 0.174442
# --
# Accuracy on patch4: 0.897568
# Loss on patch4: 0.123508
# --
# Accuracy on patch5: 0.904892
# Loss on patch5: 0.135763
# --
# Accuracy on patch6: 0.763519
# Loss on patch6: 0.210155
# --
# Accuracy on patch7: 0.778687
# Loss on patch7: 0.188402
# --
# Accuracy on patch8: 0.898605
# Loss on patch8: 0.151705
# --
# Accuracy on patch9: 0.90303
# Loss on patch9: 0.0967569
# --
# Accuracy on patch10: 0.89563
# Loss on patch10: 0.122617
# --
# Accuracy on patch11: 0.774078
# Loss on patch11: 0.203168
# --
# Accuracy on patch12: 0.883713
# Loss on patch12: 0.172782
# --
# Accuracy on patch13: 0.855911
# Loss on patch13: 0.195227
# --
# Accuracy on patch14: 0.868317
# Loss on patch14: 0.1299
# --
# Accuracy on patch15: 0.892044
# Loss on patch15: 0.0903215
# --
# Accuracy on patch16: 0.88797
# Loss on patch16: 0.123427
# --
# Accuracy on patch17: 0.916138
# Loss on patch17: 0.107339
# --
# Accuracy on patch18: 0.875351
# Loss on patch18: 0.138896
# --
# Accuracy on patch19: 0.888351
# Loss on patch19: 0.097402
# --
# Accuracy on patch20: 0.88472
# Loss on patch20: 0.136783
# --
# Accuracy on patch21: 0.890411
# Loss on patch21: 0.121594
# --
# Accuracy on patch22: 0.870987
# Loss on patch22: 0.142978
#
#
# ----Scores on test:---
# ----
#  Last epoch: 16
#  Accuracy: 0.872493;
#  Loss: 0.142399;
# --
# Accuracy on patch0: 0.862244
# Loss on patch0: 0.12633
# --
# Accuracy on patch1: 0.889389
# Loss on patch1: 0.083783
# --
# Accuracy on patch2: 0.883667
# Loss on patch2: 0.121015
# --
# Accuracy on patch3: 0.867325
# Loss on patch3: 0.147818
# --
# Accuracy on patch4: 0.885345
# Loss on patch4: 0.105554
# --
# Accuracy on patch5: 0.890427
# Loss on patch5: 0.119673
# --
# Accuracy on patch6: 0.700989
# Loss on patch6: 0.17473
# --
# Accuracy on patch7: 0.717941
# Loss on patch7: 0.155389
# --
# Accuracy on patch8: 0.880188
# Loss on patch8: 0.13171
# --
# Accuracy on patch9: 0.888168
# Loss on patch9: 0.0862154
# --
# Accuracy on patch10: 0.887741
# Loss on patch10: 0.105758
# --
# Accuracy on patch11: 0.70813
# Loss on patch11: 0.165929
# --
# Accuracy on patch12: 0.874969
# Loss on patch12: 0.147729
# --
# Accuracy on patch13: 0.845032
# Loss on patch13: 0.15499
# --
# Accuracy on patch14: 0.842041
# Loss on patch14: 0.108973
# --
# Accuracy on patch15: 0.871002
# Loss on patch15: 0.0685737
# --
# Accuracy on patch16: 0.866684
# Loss on patch16: 0.110297
# --
# Accuracy on patch17: 0.915726
# Loss on patch17: 0.0988367
# --
# Accuracy on patch18: 0.858688
# Loss on patch18: 0.112772
# --
# Accuracy on patch19: 0.871124
# Loss on patch19: 0.072314
# --
# Accuracy on patch20: 0.877472
# Loss on patch20: 0.1088
# --
# Accuracy on patch21: 0.875275
# Loss on patch21: 0.102887
# --
# Accuracy on patch22: 0.849197
# Loss on patch22: 0.110887
#
#
# ----Scores on test:---
# ----
#  Last epoch: 17
#  Accuracy: 0.852555;
#  Loss: 0.118303;
# --
# Accuracy on patch0: 0.866959
# Loss on patch0: 0.131629
# --
# Accuracy on patch1: 0.899338
# Loss on patch1: 0.0725568
# --
# Accuracy on patch2: 0.894516
# Loss on patch2: 0.123441
# --
# Accuracy on patch3: 0.870193
# Loss on patch3: 0.155359
# --
# Accuracy on patch4: 0.892303
# Loss on patch4: 0.107472
# --
# Accuracy on patch5: 0.902954
# Loss on patch5: 0.115898
# --
# Accuracy on patch6: 0.75293
# Loss on patch6: 0.189282
# --
# Accuracy on patch7: 0.768906
# Loss on patch7: 0.165699
# --
# Accuracy on patch8: 0.89415
# Loss on patch8: 0.133797
# --
# Accuracy on patch9: 0.89212
# Loss on patch9: 0.087511
# --
# Accuracy on patch10: 0.891006
# Loss on patch10: 0.0966429
# --
# Accuracy on patch11: 0.764801
# Loss on patch11: 0.177595
# --
# Accuracy on patch12: 0.885437
# Loss on patch12: 0.147186
# --
# Accuracy on patch13: 0.86348
# Loss on patch13: 0.156457
# --
# Accuracy on patch14: 0.854538
# Loss on patch14: 0.11683
# --
# Accuracy on patch15: 0.885147
# Loss on patch15: 0.0725521
# --
# Accuracy on patch16: 0.870834
# Loss on patch16: 0.1137
# --
# Accuracy on patch17: 0.920914
# Loss on patch17: 0.0804619
# --
# Accuracy on patch18: 0.875473
# Loss on patch18: 0.114033
# --
# Accuracy on patch19: 0.880157
# Loss on patch19: 0.0792199
# --
# Accuracy on patch20: 0.886765
# Loss on patch20: 0.105918
# --
# Accuracy on patch21: 0.883926
# Loss on patch21: 0.104744
# --
# Accuracy on patch22: 0.864563
# Loss on patch22: 0.116353
#
#
# ----Scores on test:---
# ----
#  Last epoch: 18
#  Accuracy: 0.867887;
#  Loss: 0.120189;
# Model saved in file: ../models/2017-06-16_15-30-59/model.ckpt
# --
# Accuracy on patch0: 0.882401
# Loss on patch0: 0.162627
# --
# Accuracy on patch1: 0.903976
# Loss on patch1: 0.0986316
# --
# Accuracy on patch2: 0.898666
# Loss on patch2: 0.149783
# --
# Accuracy on patch3: 0.886993
# Loss on patch3: 0.174768
# --
# Accuracy on patch4: 0.904434
# Loss on patch4: 0.124035
# --
# Accuracy on patch5: 0.907501
# Loss on patch5: 0.135626
# --
# Accuracy on patch6: 0.807312
# Loss on patch6: 0.212546
# --
# Accuracy on patch7: 0.824371
# Loss on patch7: 0.183977
# --
# Accuracy on patch8: 0.905121
# Loss on patch8: 0.151757
# --
# Accuracy on patch9: 0.911163
# Loss on patch9: 0.0961218
# --
# Accuracy on patch10: 0.903564
# Loss on patch10: 0.122866
# --
# Accuracy on patch11: 0.815475
# Loss on patch11: 0.199614
# --
# Accuracy on patch12: 0.890762
# Loss on patch12: 0.176748
# --
# Accuracy on patch13: 0.872269
# Loss on patch13: 0.187289
# --
# Accuracy on patch14: 0.878647
# Loss on patch14: 0.131172
# --
# Accuracy on patch15: 0.902939
# Loss on patch15: 0.0908306
# --
# Accuracy on patch16: 0.893173
# Loss on patch16: 0.131903
# --
# Accuracy on patch17: 0.91655
# Loss on patch17: 0.11244
# --
# Accuracy on patch18: 0.892151
# Loss on patch18: 0.142297
# --
# Accuracy on patch19: 0.894226
# Loss on patch19: 0.0963846
# --
# Accuracy on patch20: 0.896057
# Loss on patch20: 0.133905
# --
# Accuracy on patch21: 0.895187
# Loss on patch21: 0.123577
# --
# Accuracy on patch22: 0.880402
# Loss on patch22: 0.142415
#
#
# ----Scores on test:---
# ----
#  Last epoch: 19
#  Accuracy: 0.885363;
#  Loss: 0.142666;
# --
# Accuracy on patch0: 0.883804
# Loss on patch0: 0.180526
# --
# Accuracy on patch1: 0.914581
# Loss on patch1: 0.0941001
# --
# Accuracy on patch2: 0.901459
# Loss on patch2: 0.164042
# --
# Accuracy on patch3: 0.891205
# Loss on patch3: 0.191414
# --
# Accuracy on patch4: 0.909973
# Loss on patch4: 0.135225
# --
# Accuracy on patch5: 0.910461
# Loss on patch5: 0.143061
# --
# Accuracy on patch6: 0.8255
# Loss on patch6: 0.238958
# --
# Accuracy on patch7: 0.833405
# Loss on patch7: 0.210382
# --
# Accuracy on patch8: 0.911057
# Loss on patch8: 0.162464
# --
# Accuracy on patch9: 0.919022
# Loss on patch9: 0.104884
# --
# Accuracy on patch10: 0.906815
# Loss on patch10: 0.123828
# --
# Accuracy on patch11: 0.83107
# Loss on patch11: 0.227279
# --
# Accuracy on patch12: 0.896851
# Loss on patch12: 0.187905
# --
# Accuracy on patch13: 0.871475
# Loss on patch13: 0.20898
# --
# Accuracy on patch14: 0.890305
# Loss on patch14: 0.139045
# --
# Accuracy on patch15: 0.911789
# Loss on patch15: 0.0972452
# --
# Accuracy on patch16: 0.903259
# Loss on patch16: 0.140484
# --
# Accuracy on patch17: 0.928131
# Loss on patch17: 0.0973013
# --
# Accuracy on patch18: 0.897644
# Loss on patch18: 0.159338
# --
# Accuracy on patch19: 0.904373
# Loss on patch19: 0.104655
# --
# Accuracy on patch20: 0.895279
# Loss on patch20: 0.14944
# --
# Accuracy on patch21: 0.90007
# Loss on patch21: 0.13158
# --
# Accuracy on patch22: 0.885956
# Loss on patch22: 0.158279
#
#
# ----Scores on test:---
# ----
#  Last epoch: 20
#  Accuracy: 0.892325;
#  Loss: 0.154366;
# --
# Accuracy on patch0: 0.863663
# Loss on patch0: 0.111857
# --
# Accuracy on patch1: 0.896667
# Loss on patch1: 0.0844428
# --
# Accuracy on patch2: 0.894821
# Loss on patch2: 0.109648
# --
# Accuracy on patch3: 0.864868
# Loss on patch3: 0.153999
# --
# Accuracy on patch4: 0.87265
# Loss on patch4: 0.115018
# --
# Accuracy on patch5: 0.896179
# Loss on patch5: 0.115543
# --
# Accuracy on patch6: 0.735916
# Loss on patch6: 0.172339
# --
# Accuracy on patch7: 0.753693
# Loss on patch7: 0.152299
# --
# Accuracy on patch8: 0.876755
# Loss on patch8: 0.136931
# --
# Accuracy on patch9: 0.868179
# Loss on patch9: 0.0907687
# --
# Accuracy on patch10: 0.8871
# Loss on patch10: 0.106354
# --
# Accuracy on patch11: 0.744705
# Loss on patch11: 0.160289
# --
# Accuracy on patch12: 0.884201
# Loss on patch12: 0.14773
# --
# Accuracy on patch13: 0.854126
# Loss on patch13: 0.144997
# --
# Accuracy on patch14: 0.837952
# Loss on patch14: 0.116298
# --
# Accuracy on patch15: 0.88269
# Loss on patch15: 0.0723291
# --
# Accuracy on patch16: 0.854095
# Loss on patch16: 0.114385
# --
# Accuracy on patch17: 0.908264
# Loss on patch17: 0.107829
# --
# Accuracy on patch18: 0.862549
# Loss on patch18: 0.104507
# --
# Accuracy on patch19: 0.876938
# Loss on patch19: 0.075345
# --
# Accuracy on patch20: 0.885529
# Loss on patch20: 0.0905193
# --
# Accuracy on patch21: 0.881973
# Loss on patch21: 0.102185
# --
# Accuracy on patch22: 0.852081
# Loss on patch22: 0.105884
#
#
# ----Scores on test:---
# ----
#  Last epoch: 21
#  Accuracy: 0.858069;
#  Loss: 0.117022;
# Model saved in file: ../models/2017-06-16_15-30-59/model.ckpt
# --
# Accuracy on patch0: 0.87764
# Loss on patch0: 0.11257
# --
# Accuracy on patch1: 0.896835
# Loss on patch1: 0.0613402
# --
# Accuracy on patch2: 0.903458
# Loss on patch2: 0.104801
# --
# Accuracy on patch3: 0.880081
# Loss on patch3: 0.13183
# --
# Accuracy on patch4: 0.892685
# Loss on patch4: 0.086014
# --
# Accuracy on patch5: 0.90271
# Loss on patch5: 0.0959625
# --
# Accuracy on patch6: 0.781601
# Loss on patch6: 0.152575
# --
# Accuracy on patch7: 0.78952
# Loss on patch7: 0.131382
# --
# Accuracy on patch8: 0.906738
# Loss on patch8: 0.106984
# --
# Accuracy on patch9: 0.889389
# Loss on patch9: 0.0667977
# --
# Accuracy on patch10: 0.891602
# Loss on patch10: 0.0855557
# --
# Accuracy on patch11: 0.792953
# Loss on patch11: 0.142484
# --
# Accuracy on patch12: 0.88829
# Loss on patch12: 0.131376
# --
# Accuracy on patch13: 0.873001
# Loss on patch13: 0.132715
# --
# Accuracy on patch14: 0.854172
# Loss on patch14: 0.0921099
# --
# Accuracy on patch15: 0.876938
# Loss on patch15: 0.0573791
# --
# Accuracy on patch16: 0.875977
# Loss on patch16: 0.0943763
# --
# Accuracy on patch17: 0.926132
# Loss on patch17: 0.0670357
# --
# Accuracy on patch18: 0.888687
# Loss on patch18: 0.102256
# --
# Accuracy on patch19: 0.869751
# Loss on patch19: 0.0596173
# --
# Accuracy on patch20: 0.885773
# Loss on patch20: 0.0919965
# --
# Accuracy on patch21: 0.885208
# Loss on patch21: 0.0839165
# --
# Accuracy on patch22: 0.875046
# Loss on patch22: 0.0941858
#
#
# ----Scores on test:---
# ----
#  Last epoch: 22
#  Accuracy: 0.874095;
#  Loss: 0.0993591;
# --
# Accuracy on patch0: 0.883499
# Loss on patch0: 0.144795
# --
# Accuracy on patch1: 0.910889
# Loss on patch1: 0.0687194
# --
# Accuracy on patch2: 0.90036
# Loss on patch2: 0.138334
# --
# Accuracy on patch3: 0.889664
# Loss on patch3: 0.155394
# --
# Accuracy on patch4: 0.912003
# Loss on patch4: 0.0982534
# --
# Accuracy on patch5: 0.915131
# Loss on patch5: 0.105936
# --
# Accuracy on patch6: 0.826233
# Loss on patch6: 0.18503
# --
# Accuracy on patch7: 0.828674
# Loss on patch7: 0.163427
# --
# Accuracy on patch8: 0.910233
# Loss on patch8: 0.126533
# --
# Accuracy on patch9: 0.909363
# Loss on patch9: 0.0771938
# --
# Accuracy on patch10: 0.894012
# Loss on patch10: 0.0931051
# --
# Accuracy on patch11: 0.833588
# Loss on patch11: 0.176636
# --
# Accuracy on patch12: 0.897476
# Loss on patch12: 0.152722
# --
# Accuracy on patch13: 0.874481
# Loss on patch13: 0.169191
# --
# Accuracy on patch14: 0.882782
# Loss on patch14: 0.109969
# --
# Accuracy on patch15: 0.90181
# Loss on patch15: 0.0735429
# --
# Accuracy on patch16: 0.90509
# Loss on patch16: 0.111238
# --
# Accuracy on patch17: 0.914337
# Loss on patch17: 0.068515
# --
# Accuracy on patch18: 0.892471
# Loss on patch18: 0.132063
# --
# Accuracy on patch19: 0.893539
# Loss on patch19: 0.078417
# --
# Accuracy on patch20: 0.888474
# Loss on patch20: 0.121267
# --
# Accuracy on patch21: 0.894669
# Loss on patch21: 0.102751
# --
# Accuracy on patch22: 0.885483
# Loss on patch22: 0.122456
#
#
# ----Scores on test:---
# ----
#  Last epoch: 23
#  Accuracy: 0.888881;
#  Loss: 0.120673;
# --
# Accuracy on patch0: 0.885544
# Loss on patch0: 0.189596
# --
# Accuracy on patch1: 0.901962
# Loss on patch1: 0.11661
# --
# Accuracy on patch2: 0.902634
# Loss on patch2: 0.175829
# --
# Accuracy on patch3: 0.891434
# Loss on patch3: 0.196364
# --
# Accuracy on patch4: 0.908676
# Loss on patch4: 0.140524
# --
# Accuracy on patch5: 0.90564
# Loss on patch5: 0.162102
# --
# Accuracy on patch6: 0.83905
# Loss on patch6: 0.246293
# --
# Accuracy on patch7: 0.850418
# Loss on patch7: 0.215864
# --
# Accuracy on patch8: 0.911728
# Loss on patch8: 0.16995
# --
# Accuracy on patch9: 0.917862
# Loss on patch9: 0.103781
# --
# Accuracy on patch10: 0.905884
# Loss on patch10: 0.135944
# --
# Accuracy on patch11: 0.84375
# Loss on patch11: 0.240319
# --
# Accuracy on patch12: 0.893616
# Loss on patch12: 0.213553
# --
# Accuracy on patch13: 0.870407
# Loss on patch13: 0.228016
# --
# Accuracy on patch14: 0.892166
# Loss on patch14: 0.141897
# --
# Accuracy on patch15: 0.908539
# Loss on patch15: 0.105205
# --
# Accuracy on patch16: 0.903275
# Loss on patch16: 0.153562
# --
# Accuracy on patch17: 0.920547
# Loss on patch17: 0.128404
# --
# Accuracy on patch18: 0.904724
# Loss on patch18: 0.161001
# --
# Accuracy on patch19: 0.909332
# Loss on patch19: 0.102845
# --
# Accuracy on patch20: 0.903412
# Loss on patch20: 0.155424
# --
# Accuracy on patch21: 0.899948
# Loss on patch21: 0.134035
# --
# Accuracy on patch22: 0.892365
# Loss on patch22: 0.166048
#
#
# ----Scores on test:---
# ----
#  Last epoch: 24
#  Accuracy: 0.89404;
#  Loss: 0.164485;
# Model saved in file: ../models/2017-06-16_15-30-59/model.ckpt
# --
# Accuracy on patch0: 0.884094
# Loss on patch0: 0.173368
# --
# Accuracy on patch1: 0.915512
# Loss on patch1: 0.0785776
# --
# Accuracy on patch2: 0.903976
# Loss on patch2: 0.160549
# --
# Accuracy on patch3: 0.897629
# Loss on patch3: 0.180486
# --
# Accuracy on patch4: 0.919647
# Loss on patch4: 0.117898
# --
# Accuracy on patch5: 0.915375
# Loss on patch5: 0.127848
# --
# Accuracy on patch6: 0.852234
# Loss on patch6: 0.225741
# --
# Accuracy on patch7: 0.861404
# Loss on patch7: 0.195352
# --
# Accuracy on patch8: 0.914749
# Loss on patch8: 0.153518
# --
# Accuracy on patch9: 0.914276
# Loss on patch9: 0.0911485
# --
# Accuracy on patch10: 0.905106
# Loss on patch10: 0.104769
# --
# Accuracy on patch11: 0.863831
# Loss on patch11: 0.211951
# --
# Accuracy on patch12: 0.899002
# Loss on patch12: 0.189589
# --
# Accuracy on patch13: 0.876862
# Loss on patch13: 0.206728
# --
# Accuracy on patch14: 0.896057
# Loss on patch14: 0.131382
# --
# Accuracy on patch15: 0.919098
# Loss on patch15: 0.0862581
# --
# Accuracy on patch16: 0.907013
# Loss on patch16: 0.137335
# --
# Accuracy on patch17: 0.92067
# Loss on patch17: 0.0801396
# --
# Accuracy on patch18: 0.904449
# Loss on patch18: 0.152101
# --
# Accuracy on patch19: 0.912079
# Loss on patch19: 0.0945152
# --
# Accuracy on patch20: 0.901733
# Loss on patch20: 0.141797
# --
# Accuracy on patch21: 0.902496
# Loss on patch21: 0.121383
# --
# Accuracy on patch22: 0.897675
# Loss on patch22: 0.147361
#
#
# ----Scores on test:---
# ----
#  Last epoch: 25
#  Accuracy: 0.899346;
#  Loss: 0.143904;
# --
# Accuracy on patch0: 0.890976
# Loss on patch0: 0.172009
# --
# Accuracy on patch1: 0.92543
# Loss on patch1: 0.0872161
# --
# Accuracy on patch2: 0.907501
# Loss on patch2: 0.165144
# --
# Accuracy on patch3: 0.895767
# Loss on patch3: 0.19631
# --
# Accuracy on patch4: 0.916367
# Loss on patch4: 0.133989
# --
# Accuracy on patch5: 0.915573
# Loss on patch5: 0.141362
# --
# Accuracy on patch6: 0.847351
# Loss on patch6: 0.240862
# --
# Accuracy on patch7: 0.856049
# Loss on patch7: 0.214585
# --
# Accuracy on patch8: 0.912857
# Loss on patch8: 0.170291
# --
# Accuracy on patch9: 0.923218
# Loss on patch9: 0.107078
# --
# Accuracy on patch10: 0.91806
# Loss on patch10: 0.123957
# --
# Accuracy on patch11: 0.855835
# Loss on patch11: 0.226127
# --
# Accuracy on patch12: 0.901428
# Loss on patch12: 0.195305
# --
# Accuracy on patch13: 0.880264
# Loss on patch13: 0.210816
# --
# Accuracy on patch14: 0.895767
# Loss on patch14: 0.146926
# --
# Accuracy on patch15: 0.924133
# Loss on patch15: 0.0853197
# --
# Accuracy on patch16: 0.908508
# Loss on patch16: 0.150008
# --
# Accuracy on patch17: 0.935226
# Loss on patch17: 0.0914389
# --
# Accuracy on patch18: 0.908142
# Loss on patch18: 0.155115
# --
# Accuracy on patch19: 0.913422
# Loss on patch19: 0.101191
# --
# Accuracy on patch20: 0.910904
# Loss on patch20: 0.138676
# --
# Accuracy on patch21: 0.904327
# Loss on patch21: 0.133444
# --
# Accuracy on patch22: 0.901932
# Loss on patch22: 0.147391
#
#
# ----Scores on test:---
# ----
#  Last epoch: 26
#  Accuracy: 0.902132;
#  Loss: 0.153677;
# --
# Accuracy on patch0: 0.887573
# Loss on patch0: 0.11235
# --
# Accuracy on patch1: 0.905594
# Loss on patch1: 0.0491205
# --
# Accuracy on patch2: 0.897995
# Loss on patch2: 0.109843
# --
# Accuracy on patch3: 0.891968
# Loss on patch3: 0.130585
# --
# Accuracy on patch4: 0.908249
# Loss on patch4: 0.0839538
# --
# Accuracy on patch5: 0.916428
# Loss on patch5: 0.0891324
# --
# Accuracy on patch6: 0.834717
# Loss on patch6: 0.179458
# --
# Accuracy on patch7: 0.833801
# Loss on patch7: 0.15322
# --
# Accuracy on patch8: 0.91597
# Loss on patch8: 0.113736
# --
# Accuracy on patch9: 0.892685
# Loss on patch9: 0.0683628
# --
# Accuracy on patch10: 0.891739
# Loss on patch10: 0.0731015
# --
# Accuracy on patch11: 0.844559
# Loss on patch11: 0.163942
# --
# Accuracy on patch12: 0.903976
# Loss on patch12: 0.133418
# --
# Accuracy on patch13: 0.880447
# Loss on patch13: 0.151907
# --
# Accuracy on patch14: 0.874924
# Loss on patch14: 0.097891
# --
# Accuracy on patch15: 0.909866
# Loss on patch15: 0.0535577
# --
# Accuracy on patch16: 0.893814
# Loss on patch16: 0.0975589
# --
# Accuracy on patch17: 0.923325
# Loss on patch17: 0.0560414
# --
# Accuracy on patch18: 0.886749
# Loss on patch18: 0.105616
# --
# Accuracy on patch19: 0.895065
# Loss on patch19: 0.061302
# --
# Accuracy on patch20: 0.889648
# Loss on patch20: 0.0905683
# --
# Accuracy on patch21: 0.892044
# Loss on patch21: 0.0850097
# --
# Accuracy on patch22: 0.887634
# Loss on patch22: 0.101405
#
#
# ----Scores on test:---
# ----
#  Last epoch: 27
#  Accuracy: 0.889512;
#  Loss: 0.102656;
# Model saved in file: ../models/2017-06-16_15-30-59/model.ckpt
# --
# Accuracy on patch0: 0.893707
# Loss on patch0: 0.111344
# --
# Accuracy on patch1: 0.910522
# Loss on patch1: 0.0555152
# --
# Accuracy on patch2: 0.920029
# Loss on patch2: 0.107195
# --
# Accuracy on patch3: 0.89209
# Loss on patch3: 0.143624
# --
# Accuracy on patch4: 0.908173
# Loss on patch4: 0.0923742
# --
# Accuracy on patch5: 0.91069
# Loss on patch5: 0.104011
# --
# Accuracy on patch6: 0.837662
# Loss on patch6: 0.165785
# --
# Accuracy on patch7: 0.845825
# Loss on patch7: 0.141896
# --
# Accuracy on patch8: 0.909119
# Loss on patch8: 0.120469
# --
# Accuracy on patch9: 0.907059
# Loss on patch9: 0.0745201
# --
# Accuracy on patch10: 0.907837
# Loss on patch10: 0.0798685
# --
# Accuracy on patch11: 0.846725
# Loss on patch11: 0.151624
# --
# Accuracy on patch12: 0.89978
# Loss on patch12: 0.146635
# --
# Accuracy on patch13: 0.887009
# Loss on patch13: 0.139835
# --
# Accuracy on patch14: 0.875946
# Loss on patch14: 0.101819
# --
# Accuracy on patch15: 0.906876
# Loss on patch15: 0.0550229
# --
# Accuracy on patch16: 0.892899
# Loss on patch16: 0.104276
# --
# Accuracy on patch17: 0.933548
# Loss on patch17: 0.0599941
# --
# Accuracy on patch18: 0.907745
# Loss on patch18: 0.10269
# --
# Accuracy on patch19: 0.89537
# Loss on patch19: 0.0635109
# --
# Accuracy on patch20: 0.904968
# Loss on patch20: 0.0931484
# --
# Accuracy on patch21: 0.90094
# Loss on patch21: 0.0884463
# --
# Accuracy on patch22: 0.896896
# Loss on patch22: 0.0986122
#
#
# ----Scores on test:---
# ----
#  Last epoch: 28
#  Accuracy: 0.895279;
#  Loss: 0.104444;
# --
# Accuracy on patch0: 0.89238
# Loss on patch0: 0.110834
# --
# Accuracy on patch1: 0.912186
# Loss on patch1: 0.0481835
# --
# Accuracy on patch2: 0.916061
# Loss on patch2: 0.113245
# --
# Accuracy on patch3: 0.890839
# Loss on patch3: 0.145583
# --
# Accuracy on patch4: 0.908539
# Loss on patch4: 0.0914384
# --
# Accuracy on patch5: 0.918411
# Loss on patch5: 0.0944239
# --
# Accuracy on patch6: 0.832001
# Loss on patch6: 0.177947
# --
# Accuracy on patch7: 0.833511
# Loss on patch7: 0.156381
# --
# Accuracy on patch8: 0.909271
# Loss on patch8: 0.122924
# --
# Accuracy on patch9: 0.895874
# Loss on patch9: 0.0732588
# --
# Accuracy on patch10: 0.889633
# Loss on patch10: 0.0862997
# --
# Accuracy on patch11: 0.841431
# Loss on patch11: 0.16619
# --
# Accuracy on patch12: 0.902679
# Loss on patch12: 0.146497
# --
# Accuracy on patch13: 0.883789
# Loss on patch13: 0.149563
# --
# Accuracy on patch14: 0.876358
# Loss on patch14: 0.108346
# --
# Accuracy on patch15: 0.912979
# Loss on patch15: 0.0548478
# --
# Accuracy on patch16: 0.89325
# Loss on patch16: 0.110444
# --
# Accuracy on patch17: 0.93074
# Loss on patch17: 0.0690345
# --
# Accuracy on patch18: 0.902985
# Loss on patch18: 0.113246
# --
# Accuracy on patch19: 0.899597
# Loss on patch19: 0.0650604
# --
# Accuracy on patch20: 0.901428
# Loss on patch20: 0.0925243
# --
# Accuracy on patch21: 0.901108
# Loss on patch21: 0.0901488
# --
# Accuracy on patch22: 0.898346
# Loss on patch22: 0.100278
#
#
# ----Scores on test:---
# ----
#  Last epoch: 29
#  Accuracy: 0.893191;
#  Loss: 0.108117;
# --
# Accuracy on patch0: 0.890671
# Loss on patch0: 0.119755
# --
# Accuracy on patch1: 0.90947
# Loss on patch1: 0.075097
# --
# Accuracy on patch2: 0.902054
# Loss on patch2: 0.120652
# --
# Accuracy on patch3: 0.887482
# Loss on patch3: 0.149267
# --
# Accuracy on patch4: 0.906693
# Loss on patch4: 0.103837
# --
# Accuracy on patch5: 0.918549
# Loss on patch5: 0.105545
# --
# Accuracy on patch6: 0.832062
# Loss on patch6: 0.188386
# --
# Accuracy on patch7: 0.842453
# Loss on patch7: 0.16432
# --
# Accuracy on patch8: 0.90509
# Loss on patch8: 0.132797
# --
# Accuracy on patch9: 0.896881
# Loss on patch9: 0.0828115
# --
# Accuracy on patch10: 0.900497
# Loss on patch10: 0.0898777
# --
# Accuracy on patch11: 0.842651
# Loss on patch11: 0.173595
# --
# Accuracy on patch12: 0.895874
# Loss on patch12: 0.147845
# --
# Accuracy on patch13: 0.874008
# Loss on patch13: 0.157447
# --
# Accuracy on patch14: 0.875351
# Loss on patch14: 0.11926
# --
# Accuracy on patch15: 0.908737
# Loss on patch15: 0.0697142
# --
# Accuracy on patch16: 0.893539
# Loss on patch16: 0.113878
# --
# Accuracy on patch17: 0.911285
# Loss on patch17: 0.0826587
# --
# Accuracy on patch18: 0.882568
# Loss on patch18: 0.112172
# --
# Accuracy on patch19: 0.909531
# Loss on patch19: 0.0739854
# --
# Accuracy on patch20: 0.900497
# Loss on patch20: 0.0953365
# --
# Accuracy on patch21: 0.894974
# Loss on patch21: 0.0998761
# --
# Accuracy on patch22: 0.888275
# Loss on patch22: 0.113764
#
#
# ----Scores on test:---
# ----
#  Last epoch: 30
#  Accuracy: 0.889965;
#  Loss: 0.117038;
# Model saved in file: ../models/2017-06-16_15-30-59/model.ckpt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-17cb55838b26> in <module>()
#      24 # Note : possible values for gpu: None, '/gpu:0'. If used withing CUDA_VISIBLE_DEVICES=?, then it will use gpu number ? by default
#      25 from AxonDeepSeg.train_network import train_model
# ---> 26 train_model(path_training, path_model, config_network,path_model_init=path_model_init,gpu='/gpu:0', augmented_data=True)
#
# /Users/alzaia/anaconda/lib/python2.7/site-packages/AxonDeepSeg/train_network.pyc in train_model(path_trainingset, path_model, config, path_model_init, save_trainable, augmented_data, gpu)
#     445                 batch_x, batch_y = data_train.next_batch(batch_size, rnd=True, augmented_data=augmented_data)
#     446                 session.run(optimizer, feed_dict={x: batch_x, y: batch_y,
# --> 447                                                keep_prob: dropout})
#     448
#     449             if step % display_step == 0:
#
# /Users/alzaia/anaconda/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     715     try:
#     716       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 717                          run_metadata_ptr)
#     718       if run_metadata:
#     719         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /Users/alzaia/anaconda/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     913     if final_fetches or final_targets:
#     914       results = self._do_run(handle, final_targets, final_fetches,
# --> 915                              feed_dict_string, options, run_metadata)
#     916     else:
#     917       results = []
#
# /Users/alzaia/anaconda/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#     963     if handle is None:
#     964       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# --> 965                            target_list, options, run_metadata)
#     966     else:
#     967       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /Users/alzaia/anaconda/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#     970   def _do_call(self, fn, *args):
#     971     try:
# --> 972       return fn(*args)
#     973     except errors.OpError as e:
#     974       message = compat.as_text(e.message)
#
# /Users/alzaia/anaconda/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#     952         return tf_session.TF_Run(session, options,
#     953                                  feed_dict, fetch_list, target_list,
# --> 954                                  status, run_metadata)
#     955
#     956     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
# /Users/alzaia/Desktop/cnn_project/data_2_classes_gen/training/Train
